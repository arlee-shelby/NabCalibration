# %%
import matplotlib.pyplot as plt
import numpy as np
from lmfit import Minimizer, Parameters
import sys
import pylab as py
import pandas as pd
import csv
import matplotlib.dates as mdates
from scipy import optimize, stats
from importlib import reload
import DataAnalysis.basic_functions as bf
import DataAnalysis.mod_expo_fit_functions as modf
import DataAnalysis.bi_fit_functions as bi_fit
import DataAnalysis.pulser_fit_functions as pf
import DataAnalysis.plot_functions as plotf

sys.path.append('/Users/arleeshelby/ManitobaWork_1374/pyNab/src')
import nabPy as Nab

# %%
with open('/Users/arleeshelby/Downloads/Runparameters10_10_12_03.csv') as f:
    csv.DictReader(f)
    metadata = pd.read_csv(f)

# %%
run_numbers = list(np.arange(8622,8633)) + list(np.arange(8635,8638)) + list(np.arange(8643,8660)) + list(np.arange(8681,8695)) + list(np.arange(8696,8700)) + list(np.arange(8704,8714)) + list(np.arange(8715,8722)) + list(np.arange(8824,8833))+list(np.arange(8834,8836)) + list(np.arange(8837,8851)) + list(np.arange(8853,8866))

# %%
UDETdata, UDETtime = bf.get_energy_time_data(run_numbers,'UDET')
LDETdata, LDETtime = bf.get_energy_time_data(run_numbers,'LDET')

# %%
UDETenergy = bf.get_energy(run_numbers,UDETdata)
LDETenergy = bf.get_energy(run_numbers,LDETdata)

# %%
UDETdata_pulser, time_pulser = bf.get_energy_time_data(run_numbers,data_type='pulser',detector_type='UDET')
LDETdata_pulser, time_pulser = bf.get_energy_time_data(run_numbers,data_type='pulser',detector_type='LDET')

# %%
UDETenergy_pulser = bf.get_energy(run_numbers,UDETdata_pulser)
LDETenergy_pulser = bf.get_energy(run_numbers,LDETdata_pulser)

# %%
bin_edges = UDETdata[8715]['bin_edges']['0']['37']
bin_edges_pulser = UDETdata_pulser[8622]['bin_edges']['0']['60']
bin_edges_pulser112 = UDETdata_pulser[8622]['bin_edges']['0']['pulser BC 112']

# %%
LDETpixels = ['1009','1010','1011','1012','1013','1017','1018','1019','1020','1021','1022','1023','1026','1027','1028','1029','1030','1031','1032',
               '1033','1037','1038','1039','1040','1041','1042','1043','1044','1047','1048','1049','1050','1051','1052','1053','1054','1055','1056',
               '1060','1061','1062','1062','1063','1064','1065','1066','1067','1068','1069','1072','1073','1074','1075','1076','1077','1078','1079','1080',
               '1081','1084','1085','1086','1087','1088','1089','1090','1091','1092','1094','1095','1096','1098','1099','1100','1101','1102','1105',
               '1107','1108','1109','1111','1116','1117']

# %%
UDETpixels = ['9','11','12','17','19','20','21','26','27','28','29','30','31','32','37','38','39','40','41','42','43','47','48','49','50','51','52',
          '53','54','55','60','61','62','63','64','65','66','67','72','73','74','75','76','77','78','79','84','85','86','87','88','89','90','91',
          '94','95','96','97','98','99','100','101','102','105','106','107','108','109','110','115','117']

# %%
UDET_df = bf.get_results_df(bi_fit.get_UDETbi_fit_results, UDETenergy, bin_edges, UDETpixels, run_numbers, plot=False,detector_type='UDET')
# Out:
# failed Bi fit for run: 8647, pixel: 17, region 1
# failed Bi fit for run: 8828, pixel: 17, region 1
# failed Bi fit for run: 8847, pixel: 17, region 1
# failed Bi fit for run: 8859, pixel: 19, region 1
# run: 8630, pixel: 27 too low amp, region 1
# failed Bi fit for run: 8689, pixel: 27, region 1
# failed Bi fit for run: 8840, pixel: 27, region 1
# run: 8624, pixel: 29 too low amp, region 2
# failed Bi fit for run: 8834, pixel: 29, region 1
# failed Bi fit for run: 8690, pixel: 30, region 1
# failed Bi fit for run: 8690, pixel: 30, region 2
# failed Bi fit for run: 8715, pixel: 37, region 1
# failed Bi fit for run: 8624, pixel: 43, region 1
# run: 8624, pixel: 43 too low amp, region 2
# run: 8630, pixel: 43 too low amp, region 1
# run: 8630, pixel: 43 too low amp, region 2
# failed Bi fit for run: 8630, pixel: 43, region 3
# run: 8637, pixel: 43 too low amp, region 1
# failed Bi fit for run: 8637, pixel: 43, region 2
# run: 8683, pixel: 43 too low amp, region 1
# run: 8683, pixel: 43 too low amp, region 2
# run: 8694, pixel: 43 too low amp, region 1
# failed Bi fit for run: 8694, pixel: 43, region 2
# run: 8834, pixel: 43 too low amp, region 2
# failed Bi fit for run: 8860, pixel: 43, region 1
# failed Bi fit for run: 8860, pixel: 43, region 2
# failed Bi fit for run: 8623, pixel: 47, region 1
# failed Bi fit for run: 8623, pixel: 48, region 1
# run: 8682, pixel: 48 too low amp, region 2
# failed Bi fit for run: 8636, pixel: 50, region 1
# failed Bi fit for run: 8835, pixel: 51, region 1
# failed Bi fit for run: 8629, pixel: 52, region 1
# run: 8655, pixel: 52 too low amp, region 1
# run: 8655, pixel: 52 too low amp, region 2
# failed Bi fit for run: 8709, pixel: 52, region 1
# failed Bi fit for run: 8684, pixel: 53, region 1
# failed Bi fit for run: 8839, pixel: 54, region 3
# failed Bi fit for run: 8848, pixel: 54, region 3
# failed Bi fit for run: 8861, pixel: 54, region 3
# failed Bi fit for run: 8635, pixel: 63, region 2
# run: 8622, pixel: 64 too low amp, region 2
# failed Bi fit for run: 8845, pixel: 64, region 1
# failed Bi fit for run: 8654, pixel: 65, region 1
# failed Bi fit for run: 8625, pixel: 66, region 1
# run: 8690, pixel: 66 too low amp, region 1
# run: 8690, pixel: 66 too low amp, region 2
# run: 8832, pixel: 66 too low amp, region 1
# run: 8832, pixel: 66 too low amp, region 2
# failed Bi fit for run: 8713, pixel: 67, region 1
# failed Bi fit for run: 8713, pixel: 67, region 2
# failed Bi fit for run: 8713, pixel: 67, region 3
# run: 8716, pixel: 67 too low amp, region 1
# failed Bi fit for run: 8716, pixel: 67, region 2
# failed Bi fit for run: 8716, pixel: 67, region 3
# run: 8626, pixel: 72 too low amp, region 1
# run: 8626, pixel: 72 too low amp, region 2
# failed Bi fit for run: 8685, pixel: 72, region 1
# failed Bi fit for run: 8685, pixel: 72, region 2
# failed Bi fit for run: 8837, pixel: 72, region 1
# run: 8837, pixel: 72 too low amp, region 2
# failed Bi fit for run: 8840, pixel: 79, region 1
# run: 8644, pixel: 86 too low amp, region 1
# run: 8697, pixel: 86 too low amp, region 1
# failed Bi fit for run: 8626, pixel: 87, region 1
# failed Bi fit for run: 8685, pixel: 87, region 1
# run: 8837, pixel: 87 too low amp, region 1
# run: 8837, pixel: 87 too low amp, region 2
# run: 8693, pixel: 88 too low amp, region 1
# run: 8693, pixel: 88 too low amp, region 2
# failed Bi fit for run: 8861, pixel: 88, region 1
# run: 8623, pixel: 89 too low amp, region 1
# failed Bi fit for run: 8623, pixel: 89, region 2
# run: 8682, pixel: 89 too low amp, region 1
# run: 8835, pixel: 89 too low amp, region 1
# run: 8835, pixel: 89 too low amp, region 2
# run: 8659, pixel: 94 too low amp, region 2
# failed Bi fit for run: 8718, pixel: 95, region 1
# failed Bi fit for run: 8718, pixel: 95, region 2
# run: 8706, pixel: 100 too low amp, region 2
# failed Bi fit for run: 8713, pixel: 100, region 1
# run: 8845, pixel: 100 too low amp, region 1
# failed Bi fit for run: 8850, pixel: 100, region 1
# failed Bi fit for run: 8838, pixel: 102, region 1
# failed Bi fit for run: 8652, pixel: 109, region 1
# run: 8706, pixel: 109 too low amp, region 1
# run: 8706, pixel: 109 too low amp, region 2
# run: 8837, pixel: 109 too low amp, region 1
# run: 8837, pixel: 109 too low amp, region 2
# failed Bi fit for run: 8837, pixel: 109, region 3
# run: 8849, pixel: 109 too low amp, region 2
# run: 8850, pixel: 109 too low amp, region 1
# run: 8850, pixel: 109 too low amp, region 2
# run: 8626, pixel: 110 too low amp, region 1
# run: 8626, pixel: 110 too low amp, region 2
# run: 8626, pixel: 110 too low amp, region 3
# run: 8649, pixel: 110 too low amp, region 1
# run: 8704, pixel: 110 too low amp, region 1
# run: 8704, pixel: 110 too low amp, region 2
# run: 8704, pixel: 110 too low amp, region 3
# failed Bi fit for run: 8713, pixel: 110, region 1
# run: 8713, pixel: 110 too low amp, region 2
# run: 8716, pixel: 110 too low amp, region 1
# run: 8844, pixel: 110 too low amp, region 1
# run: 8844, pixel: 110 too low amp, region 2
# run: 8844, pixel: 110 too low amp, region 3
# run: 8845, pixel: 110 too low amp, region 1

# %%
LDET_df = bf.get_results_df(bi_fit.get_UDETbi_fit_results, LDETenergy, bin_edges, LDETpixels, run_numbers, plot=False,detector_type='LDET')
# Out:
# run: 8720, pixel: 1011 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8720, pixel: 1011, region 3
# failed Bi fit for run: 8826, pixel: 1011, region 3
# failed Bi fit for run: 8857, pixel: 1011, region 3
# LDET average too low, run 8644, pixel 1012
# failed Bi fit for run: 8644, pixel: 1012, region 2
# LDET average too low, run 8697, pixel 1012
# run: 8697, pixel: 1012 too low amp, region 2
# failed Bi fit for run: 8719, pixel: 1012, region 1
# failed Bi fit for run: 8829, pixel: 1012, region 1
# LDET average too low, run 8863, pixel 1012
# failed Bi fit for run: 8863, pixel: 1012, region 2
# LDET average too low, run 8626, pixel 1013
# failed Bi fit for run: 8626, pixel: 1013, region 2
# failed Bi fit for run: 8626, pixel: 1013, region 3
# LDET average too low, run 8644, pixel 1013
# LDET average too low, run 8651, pixel 1013
# LDET average too low, run 8685, pixel 1013
# failed Bi fit for run: 8685, pixel: 1013, region 2
# LDET average too low, run 8697, pixel 1013
# LDET average too low, run 8705, pixel 1013
# LDET average too low, run 8837, pixel 1013
# failed Bi fit for run: 8837, pixel: 1013, region 2
# LDET average too low, run 8849, pixel 1013
# LDET average too low, run 8863, pixel 1013
# run: 8863, pixel: 1013 too low amp, region 2
# failed Bi fit for run: 8719, pixel: 1017, region 1
# run: 8719, pixel: 1017 too low amp, region 3
# run: 8829, pixel: 1017 too low amp, region 3
# failed Bi fit for run: 8826, pixel: 1020, region 1
# failed Bi fit for run: 8826, pixel: 1020, region 2
# failed Bi fit for run: 8857, pixel: 1020, region 2
# failed Bi fit for run: 8635, pixel: 1021, region 1
# failed Bi fit for run: 8635, pixel: 1021, region 3
# LDET average too low, run 8636, pixel 1021
# failed Bi fit for run: 8636, pixel: 1021, region 2
# run: 8636, pixel: 1021 too low amp, region 3
# failed Bi fit for run: 8652, pixel: 1021, region 1
# failed Bi fit for run: 8652, pixel: 1021, region 2
# failed Bi fit for run: 8652, pixel: 1021, region 3
# failed Bi fit for run: 8692, pixel: 1021, region 1
# failed Bi fit for run: 8692, pixel: 1021, region 2
# run: 8692, pixel: 1021 too low amp, region 3
# LDET average too low, run 8693, pixel 1021
# failed Bi fit for run: 8693, pixel: 1021, region 2
# failed Bi fit for run: 8693, pixel: 1021, region 3
# failed Bi fit for run: 8706, pixel: 1021, region 1
# failed Bi fit for run: 8706, pixel: 1021, region 2
# run: 8706, pixel: 1021 too low amp, region 3
# failed Bi fit for run: 8718, pixel: 1021, region 1
# run: 8718, pixel: 1021 too low amp, region 2
# run: 8718, pixel: 1021 too low amp, region 3
# failed Bi fit for run: 8719, pixel: 1021, region 1
# failed Bi fit for run: 8719, pixel: 1021, region 2
# run: 8719, pixel: 1021 too low amp, region 3
# failed Bi fit for run: 8829, pixel: 1021, region 1
# run: 8829, pixel: 1021 too low amp, region 3
# failed Bi fit for run: 8830, pixel: 1021, region 2
# failed Bi fit for run: 8830, pixel: 1021, region 3
# failed Bi fit for run: 8850, pixel: 1021, region 1
# failed Bi fit for run: 8850, pixel: 1021, region 2
# run: 8850, pixel: 1021 too low amp, region 3
# LDET average too low, run 8861, pixel 1021
# failed Bi fit for run: 8861, pixel: 1021, region 2
# failed Bi fit for run: 8861, pixel: 1021, region 3
# failed Bi fit for run: 8862, pixel: 1021, region 1
# failed Bi fit for run: 8862, pixel: 1021, region 2
# failed Bi fit for run: 8862, pixel: 1021, region 3
# run: 8622, pixel: 1022 too low amp, sig1 or sig2 region 1
# LDET average too low, run 8681, pixel 1022
# LDET average too low, run 8628, pixel 1023
# LDET average too low, run 8687, pixel 1023
# LDET average too low, run 8720, pixel 1023
# LDET average too low, run 8826, pixel 1023
# LDET average too low, run 8842, pixel 1023
# LDET average too low, run 8857, pixel 1023
# run: 8626, pixel: 1026 too low amp, sig1 or sig2 region 1
# LDET average too low, run 8685, pixel 1026
# LDET average too low, run 8717, pixel 1026
# run: 8717, pixel: 1026 too low amp, region 2
# LDET average too low, run 8825, pixel 1026
# run: 8825, pixel: 1026 too low amp, region 2
# LDET average too low, run 8837, pixel 1026
# LDET average too low, run 8864, pixel 1026
# failed Bi fit for run: 8864, pixel: 1026, region 2
# LDET average too low, run 8644, pixel 1028
# failed Bi fit for run: 8644, pixel: 1028, region 2
# failed Bi fit for run: 8644, pixel: 1028, region 3
# LDET average too low, run 8697, pixel 1028
# failed Bi fit for run: 8697, pixel: 1028, region 2
# run: 8697, pixel: 1028 too low amp, region 3
# LDET average too low, run 8863, pixel 1028
# failed Bi fit for run: 8863, pixel: 1028, region 2
# run: 8863, pixel: 1028 too low amp, region 3
# failed Bi fit for run: 8644, pixel: 1029, region 1
# failed Bi fit for run: 8644, pixel: 1029, region 2
# LDET average too low, run 8697, pixel 1029
# failed Bi fit for run: 8717, pixel: 1029, region 1
# LDET average too low, run 8863, pixel 1029
# run: 8636, pixel: 1030 too low amp, sig1 or sig2 region 1
# run: 8685, pixel: 1030 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8718, pixel: 1030, region 1
# failed Bi fit for run: 8830, pixel: 1030, region 1
# run: 8861, pixel: 1030 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8693, pixel: 1031, region 1
# failed Bi fit for run: 8830, pixel: 1031, region 1
# failed Bi fit for run: 8623, pixel: 1032, region 1
# failed Bi fit for run: 8623, pixel: 1032, region 2
# failed Bi fit for run: 8629, pixel: 1032, region 1
# run: 8629, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8644, pixel: 1032, region 1
# run: 8644, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8649, pixel: 1032, region 1
# run: 8649, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8682, pixel: 1032, region 1
# run: 8682, pixel: 1032 too low amp, region 2
# run: 8682, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8688, pixel: 1032, region 1
# run: 8688, pixel: 1032 too low amp, region 3
# LDET average too low, run 8697, pixel 1032
# failed Bi fit for run: 8697, pixel: 1032, region 2
# failed Bi fit for run: 8697, pixel: 1032, region 3
# failed Bi fit for run: 8713, pixel: 1032, region 1
# run: 8713, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8716, pixel: 1032, region 1
# run: 8716, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8717, pixel: 1032, region 1
# run: 8717, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8825, pixel: 1032, region 1
# run: 8825, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8835, pixel: 1032, region 1
# run: 8835, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8841, pixel: 1032, region 1
# run: 8841, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8845, pixel: 1032, region 1
# run: 8845, pixel: 1032 too low amp, region 2
# run: 8845, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8863, pixel: 1032, region 1
# run: 8863, pixel: 1032 too low amp, region 3
# failed Bi fit for run: 8864, pixel: 1032, region 1
# failed Bi fit for run: 8864, pixel: 1032, region 3
# LDET average too low, run 8626, pixel 1033
# failed Bi fit for run: 8626, pixel: 1033, region 2
# run: 8627, pixel: 1033 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8659, pixel: 1033, region 1
# LDET average too low, run 8685, pixel 1033
# run: 8685, pixel: 1033 too low amp, region 2
# LDET average too low, run 8686, pixel 1033
# LDET average too low, run 8837, pixel 1033
# failed Bi fit for run: 8837, pixel: 1033, region 2
# LDET average too low, run 8838, pixel 1033
# failed Bi fit for run: 8626, pixel: 1037, region 2
# failed Bi fit for run: 8704, pixel: 1037, region 1
# failed Bi fit for run: 8626, pixel: 1040, region 1
# LDET average too low, run 8644, pixel 1040
# failed Bi fit for run: 8644, pixel: 1040, region 2
# LDET average too low, run 8650, pixel 1040
# run: 8650, pixel: 1040 too low amp, region 2
# LDET average too low, run 8697, pixel 1040
# run: 8697, pixel: 1040 too low amp, region 2
# LDET average too low, run 8704, pixel 1040
# run: 8704, pixel: 1040 too low amp, region 2
# LDET average too low, run 8844, pixel 1040
# run: 8844, pixel: 1040 too low amp, region 2
# LDET average too low, run 8863, pixel 1040
# run: 8863, pixel: 1040 too low amp, region 2
# LDET average too low, run 8626, pixel 1041
# failed Bi fit for run: 8626, pixel: 1041, region 2
# failed Bi fit for run: 8632, pixel: 1041, region 1
# run: 8636, pixel: 1041 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8637, pixel: 1041, region 1
# LDET average too low, run 8685, pixel 1041
# run: 8693, pixel: 1041 too low amp, sig1 or sig2 region 1
# run: 8707, pixel: 1041 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8707, pixel: 1041, region 2
# LDET average too low, run 8837, pixel 1041
# run: 8861, pixel: 1041 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8624, pixel: 1042, region 1
# LDET average too low, run 8644, pixel 1042
# run: 8644, pixel: 1042 too low amp, region 2
# LDET average too low, run 8697, pixel 1042
# failed Bi fit for run: 8697, pixel: 1042, region 2
# run: 8834, pixel: 1042 too low amp, sig1 or sig2 region 1
# LDET average too low, run 8863, pixel 1042
# failed Bi fit for run: 8863, pixel: 1042, region 2
# run: 8626, pixel: 1043 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8626, pixel: 1043, region 3
# failed Bi fit for run: 8630, pixel: 1043, region 1
# failed Bi fit for run: 8630, pixel: 1043, region 3
# failed Bi fit for run: 8644, pixel: 1043, region 1
# failed Bi fit for run: 8648, pixel: 1043, region 1
# run: 8648, pixel: 1043 too low amp, region 2
# run: 8648, pixel: 1043 too low amp, region 3
# failed Bi fit for run: 8651, pixel: 1043, region 1
# run: 8651, pixel: 1043 too low amp, region 3
# LDET average too low, run 8685, pixel 1043
# failed Bi fit for run: 8685, pixel: 1043, region 3
# failed Bi fit for run: 8689, pixel: 1043, region 1
# failed Bi fit for run: 8689, pixel: 1043, region 3
# failed Bi fit for run: 8697, pixel: 1043, region 1
# run: 8697, pixel: 1043 too low amp, region 2
# run: 8697, pixel: 1043 too low amp, region 3
# failed Bi fit for run: 8705, pixel: 1043, region 1
# run: 8705, pixel: 1043 too low amp, region 2
# failed Bi fit for run: 8705, pixel: 1043, region 3
# failed Bi fit for run: 8715, pixel: 1043, region 1
# run: 8715, pixel: 1043 too low amp, region 2
# failed Bi fit for run: 8715, pixel: 1043, region 3
# LDET average too low, run 8837, pixel 1043
# run: 8837, pixel: 1043 too low amp, region 2
# run: 8837, pixel: 1043 too low amp, region 3
# failed Bi fit for run: 8840, pixel: 1043, region 1
# run: 8840, pixel: 1043 too low amp, region 3
# failed Bi fit for run: 8846, pixel: 1043, region 1
# run: 8846, pixel: 1043 too low amp, region 2
# run: 8846, pixel: 1043 too low amp, region 3
# failed Bi fit for run: 8849, pixel: 1043, region 1
# failed Bi fit for run: 8849, pixel: 1043, region 2
# run: 8849, pixel: 1043 too low amp, region 3
# failed Bi fit for run: 8863, pixel: 1043, region 1
# run: 8863, pixel: 1043 too low amp, region 2
# failed Bi fit for run: 8863, pixel: 1043, region 3
# LDET average too low, run 8650, pixel 1044
# failed Bi fit for run: 8650, pixel: 1044, region 2
# LDET average too low, run 8704, pixel 1044
# failed Bi fit for run: 8704, pixel: 1044, region 2
# LDET average too low, run 8844, pixel 1044
# failed Bi fit for run: 8844, pixel: 1044, region 2
# failed Bi fit for run: 8651, pixel: 1047, region 1
# run: 8705, pixel: 1047 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8849, pixel: 1047, region 1
# run: 8849, pixel: 1047 too low amp, region 2
# LDET average too low, run 8626, pixel 1048
# run: 8626, pixel: 1048 too low amp, region 2
# failed Bi fit for run: 8626, pixel: 1048, region 3
# LDET average too low, run 8650, pixel 1048
# LDET average too low, run 8685, pixel 1048
# run: 8685, pixel: 1048 too low amp, region 2
# LDET average too low, run 8704, pixel 1048
# failed Bi fit for run: 8704, pixel: 1048, region 2
# failed Bi fit for run: 8705, pixel: 1048, region 1
# LDET average too low, run 8837, pixel 1048
# run: 8837, pixel: 1048 too low amp, region 2
# LDET average too low, run 8844, pixel 1048
# run: 8844, pixel: 1048 too low amp, region 2
# run: 8849, pixel: 1048 too low amp, region 2
# failed Bi fit for run: 8687, pixel: 1049, region 1
# failed Bi fit for run: 8704, pixel: 1049, region 1
# failed Bi fit for run: 8637, pixel: 1052, region 1
# failed Bi fit for run: 8687, pixel: 1052, region 1
# failed Bi fit for run: 8704, pixel: 1052, region 1
# failed Bi fit for run: 8842, pixel: 1052, region 1
# failed Bi fit for run: 8844, pixel: 1052, region 1
# failed Bi fit for run: 8844, pixel: 1052, region 2
# LDET average too low, run 8650, pixel 1053
# run: 8683, pixel: 1053 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8694, pixel: 1053, region 1
# LDET average too low, run 8704, pixel 1053
# run: 8704, pixel: 1053 too low amp, region 2
# LDET average too low, run 8844, pixel 1053
# run: 8844, pixel: 1053 too low amp, region 2
# failed Bi fit for run: 8854, pixel: 1053, region 1
# run: 8630, pixel: 1054 too low amp, region 2
# failed Bi fit for run: 8635, pixel: 1054, region 2
# failed Bi fit for run: 8689, pixel: 1054, region 2
# run: 8828, pixel: 1054 too low amp, region 2
# failed Bi fit for run: 8840, pixel: 1054, region 1
# failed Bi fit for run: 8862, pixel: 1054, region 2
# LDET average too low, run 8626, pixel 1055
# run: 8626, pixel: 1055 too low amp, region 2
# LDET average too low, run 8685, pixel 1055
# run: 8685, pixel: 1055 too low amp, region 2
# failed Bi fit for run: 8685, pixel: 1055, region 3
# failed Bi fit for run: 8689, pixel: 1055, region 1
# failed Bi fit for run: 8689, pixel: 1055, region 2
# LDET average too low, run 8837, pixel 1055
# failed Bi fit for run: 8837, pixel: 1055, region 2
# failed Bi fit for run: 8840, pixel: 1055, region 1
# failed Bi fit for run: 8844, pixel: 1056, region 1
# failed Bi fit for run: 8850, pixel: 1060, region 1
# failed Bi fit for run: 8861, pixel: 1063, region 1
# failed Bi fit for run: 8861, pixel: 1063, region 2
# failed Bi fit for run: 8682, pixel: 1064, region 1
# run: 8835, pixel: 1064 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8649, pixel: 1065, region 1
# run: 8654, pixel: 1065 too low amp, sig1 or sig2 region 1
# LDET average too low, run 8708, pixel 1065
# failed Bi fit for run: 8713, pixel: 1065, region 1
# LDET average too low, run 8854, pixel 1065
# run: 8854, pixel: 1065 too low amp, region 2
# run: 8654, pixel: 1066 too low amp, sig1 or sig2 region 1
# run: 8654, pixel: 1066 too low amp, region 2
# run: 8708, pixel: 1066 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8832, pixel: 1066, region 1
# run: 8854, pixel: 1066 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8631, pixel: 1067, region 1
# failed Bi fit for run: 8690, pixel: 1067, region 1
# failed Bi fit for run: 8839, pixel: 1067, region 1
# failed Bi fit for run: 8623, pixel: 1068, region 1
# LDET average too low, run 8682, pixel 1068
# failed Bi fit for run: 8682, pixel: 1068, region 2
# LDET average too low, run 8835, pixel 1068
# failed Bi fit for run: 8835, pixel: 1068, region 2
# LDET average too low, run 8628, pixel 1069
# LDET average too low, run 8687, pixel 1069
# LDET average too low, run 8842, pixel 1069
# LDET average too low, run 8653, pixel 1072
# failed Bi fit for run: 8693, pixel: 1072, region 1
# LDET average too low, run 8707, pixel 1072
# failed Bi fit for run: 8707, pixel: 1072, region 2
# LDET average too low, run 8853, pixel 1072
# run: 8653, pixel: 1073 too low amp, sig1 or sig2 region 1
# LDET average too low, run 8707, pixel 1073
# run: 8707, pixel: 1073 too low amp, region 2
# run: 8853, pixel: 1073 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8629, pixel: 1074, region 1
# failed Bi fit for run: 8715, pixel: 1074, region 1
# LDET average too low, run 8648, pixel 1075
# run: 8648, pixel: 1075 too low amp, region 2
# failed Bi fit for run: 8648, pixel: 1075, region 3
# failed Bi fit for run: 8653, pixel: 1076, region 1
# failed Bi fit for run: 8707, pixel: 1076, region 1
# failed Bi fit for run: 8648, pixel: 1077, region 1
# failed Bi fit for run: 8682, pixel: 1077, region 1
# failed Bi fit for run: 8835, pixel: 1077, region 1
# failed Bi fit for run: 8841, pixel: 1077, region 1
# failed Bi fit for run: 8841, pixel: 1078, region 1
# LDET average too low, run 8625, pixel 1079
# run: 8625, pixel: 1079 too low amp, region 2
# failed Bi fit for run: 8636, pixel: 1079, region 1
# failed Bi fit for run: 8646, pixel: 1079, region 1
# LDET average too low, run 8684, pixel 1079
# run: 8684, pixel: 1079 too low amp, region 2
# LDET average too low, run 8832, pixel 1079
# failed Bi fit for run: 8832, pixel: 1079, region 2
# failed Bi fit for run: 8848, pixel: 1079, region 1
# run: 8636, pixel: 1080 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8653, pixel: 1080, region 1
# failed Bi fit for run: 8682, pixel: 1080, region 1
# failed Bi fit for run: 8693, pixel: 1080, region 1
# failed Bi fit for run: 8707, pixel: 1080, region 1
# run: 8853, pixel: 1080 too low amp, sig1 or sig2 region 1
# run: 8861, pixel: 1080 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8623, pixel: 1081, region 1
# failed Bi fit for run: 8648, pixel: 1081, region 1
# failed Bi fit for run: 8682, pixel: 1081, region 1
# failed Bi fit for run: 8688, pixel: 1081, region 1
# failed Bi fit for run: 8715, pixel: 1081, region 2
# failed Bi fit for run: 8835, pixel: 1081, region 1
# failed Bi fit for run: 8846, pixel: 1081, region 1
# failed Bi fit for run: 8624, pixel: 1084, region 1
# LDET average too low, run 8654, pixel 1084
# failed Bi fit for run: 8654, pixel: 1084, region 2
# LDET average too low, run 8708, pixel 1084
# run: 8708, pixel: 1084 too low amp, region 2
# LDET average too low, run 8854, pixel 1084
# run: 8854, pixel: 1084 too low amp, region 2
# failed Bi fit for run: 8860, pixel: 1084, region 1
# failed Bi fit for run: 8860, pixel: 1084, region 2
# failed Bi fit for run: 8715, pixel: 1085, region 1
# failed Bi fit for run: 8630, pixel: 1086, region 1
# run: 8689, pixel: 1086 too low amp, sig1 or sig2 region 1
# LDET average too low, run 8840, pixel 1086
# failed Bi fit for run: 8624, pixel: 1088, region 1
# LDET average too low, run 8637, pixel 1088
# failed Bi fit for run: 8637, pixel: 1088, region 2
# LDET average too low, run 8694, pixel 1088
# failed Bi fit for run: 8694, pixel: 1088, region 2
# run: 8853, pixel: 1088 too low amp, sig1 or sig2 region 1
# LDET average too low, run 8860, pixel 1088
# run: 8860, pixel: 1088 too low amp, region 2
# LDET average too low, run 8624, pixel 1089
# failed Bi fit for run: 8624, pixel: 1089, region 2
# failed Bi fit for run: 8630, pixel: 1089, region 1
# failed Bi fit for run: 8645, pixel: 1089, region 1
# LDET average too low, run 8647, pixel 1089
# LDET average too low, run 8683, pixel 1089
# failed Bi fit for run: 8683, pixel: 1089, region 2
# failed Bi fit for run: 8698, pixel: 1089, region 1
# LDET average too low, run 8828, pixel 1089
# LDET average too low, run 8834, pixel 1089
# failed Bi fit for run: 8846, pixel: 1089, region 1
# LDET average too low, run 8847, pixel 1089
# failed Bi fit for run: 8847, pixel: 1089, region 2
# LDET average too low, run 8630, pixel 1092
# LDET average too low, run 8689, pixel 1092
# LDET average too low, run 8840, pixel 1092
# run: 8637, pixel: 1094 too low amp, sig1 or sig2 region 1
# run: 8694, pixel: 1094 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8854, pixel: 1094, region 1
# run: 8860, pixel: 1094 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8624, pixel: 1095, region 1
# run: 8647, pixel: 1095 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8654, pixel: 1095, region 1
# failed Bi fit for run: 8683, pixel: 1095, region 1
# failed Bi fit for run: 8828, pixel: 1095, region 1
# failed Bi fit for run: 8834, pixel: 1095, region 1
# run: 8847, pixel: 1095 too low amp, sig1 or sig2 region 1
# run: 8630, pixel: 1096 too low amp, sig1 or sig2 region 1
# run: 8689, pixel: 1096 too low amp, sig1 or sig2 region 1
# run: 8689, pixel: 1096 too low amp, region 2
# failed Bi fit for run: 8840, pixel: 1096, region 1
# LDET average too low, run 8624, pixel 1099
# failed Bi fit for run: 8624, pixel: 1099, region 2
# failed Bi fit for run: 8625, pixel: 1099, region 1
# LDET average too low, run 8683, pixel 1099
# run: 8683, pixel: 1099 too low amp, region 2
# failed Bi fit for run: 8832, pixel: 1099, region 1
# failed Bi fit for run: 8832, pixel: 1099, region 2
# LDET average too low, run 8834, pixel 1099
# failed Bi fit for run: 8834, pixel: 1099, region 2
# failed Bi fit for run: 8631, pixel: 1100, region 1
# failed Bi fit for run: 8631, pixel: 1100, region 2
# failed Bi fit for run: 8631, pixel: 1100, region 3
# LDET average too low, run 8647, pixel 1100
# run: 8647, pixel: 1100 too low amp, region 2
# LDET average too low, run 8690, pixel 1100
# run: 8690, pixel: 1100 too low amp, region 2
# LDET average too low, run 8828, pixel 1100
# failed Bi fit for run: 8828, pixel: 1100, region 2
# LDET average too low, run 8839, pixel 1100
# failed Bi fit for run: 8839, pixel: 1100, region 2
# failed Bi fit for run: 8847, pixel: 1100, region 1
# failed Bi fit for run: 8847, pixel: 1100, region 2
# run: 8637, pixel: 1101 too low amp, sig1 or sig2 region 1
# LDET average too low, run 8656, pixel 1101
# failed Bi fit for run: 8656, pixel: 1101, region 2
# failed Bi fit for run: 8656, pixel: 1101, region 3
# failed Bi fit for run: 8694, pixel: 1101, region 1
# LDET average too low, run 8710, pixel 1101
# run: 8710, pixel: 1101 too low amp, region 2
# failed Bi fit for run: 8710, pixel: 1101, region 3
# LDET average too low, run 8856, pixel 1101
# failed Bi fit for run: 8856, pixel: 1101, region 2
# run: 8860, pixel: 1101 too low amp, sig1 or sig2 region 1
# LDET average too low, run 8624, pixel 1102
# LDET average too low, run 8625, pixel 1102
# run: 8625, pixel: 1102 too low amp, region 2
# LDET average too low, run 8683, pixel 1102
# LDET average too low, run 8684, pixel 1102
# run: 8684, pixel: 1102 too low amp, region 2
# LDET average too low, run 8832, pixel 1102
# failed Bi fit for run: 8832, pixel: 1102, region 2
# LDET average too low, run 8834, pixel 1102
# failed Bi fit for run: 8646, pixel: 1105, region 1
# LDET average too low, run 8647, pixel 1105
# run: 8647, pixel: 1105 too low amp, region 2
# failed Bi fit for run: 8684, pixel: 1105, region 1
# LDET average too low, run 8828, pixel 1105
# run: 8828, pixel: 1105 too low amp, region 2
# LDET average too low, run 8847, pixel 1105
# failed Bi fit for run: 8847, pixel: 1105, region 2
# failed Bi fit for run: 8865, pixel: 1105, region 1
# failed Bi fit for run: 8643, pixel: 1107, region 1
# LDET average too low, run 8655, pixel 1107
# LDET average too low, run 8709, pixel 1107
# LDET average too low, run 8855, pixel 1107
# LDET average too low, run 8646, pixel 1108
# failed Bi fit for run: 8684, pixel: 1108, region 1
# failed Bi fit for run: 8827, pixel: 1108, region 1
# LDET average too low, run 8848, pixel 1108
# failed Bi fit for run: 8848, pixel: 1108, region 2
# LDET average too low, run 8647, pixel 1109
# run: 8647, pixel: 1109 too low amp, region 2
# failed Bi fit for run: 8647, pixel: 1109, region 3
# LDET average too low, run 8828, pixel 1109
# failed Bi fit for run: 8828, pixel: 1109, region 2
# LDET average too low, run 8847, pixel 1109
# failed Bi fit for run: 8847, pixel: 1109, region 2
# LDET average too low, run 8625, pixel 1111
# run: 8625, pixel: 1111 too low amp, region 2
# run: 8655, pixel: 1111 too low amp, sig1 or sig2 region 1
# run: 8655, pixel: 1111 too low amp, region 2
# LDET average too low, run 8684, pixel 1111
# run: 8684, pixel: 1111 too low amp, region 2
# LDET average too low, run 8709, pixel 1111
# LDET average too low, run 8832, pixel 1111
# failed Bi fit for run: 8832, pixel: 1111, region 2
# run: 8855, pixel: 1111 too low amp, sig1 or sig2 region 1
# failed Bi fit for run: 8855, pixel: 1116, region 1
# failed Bi fit for run: 8646, pixel: 1117, region 1
# failed Bi fit for run: 8848, pixel: 1117, region 1

# %%
# test_runs = [8622,8623,8624,8637,8649,8654,8684,8685,8689,8690,8706,8716,8830,8835,8837,8845,8850,8860]
# test_pixels = ['20','27','30','32','43','64','66','72','87','89','95','109','110']
# test_runs = [8624,8628,8643,8644,8693,8696,8712,8718,8719,8720,8829,8837,8838]
# test_pixels = ['1012','1020','1026','1030','1033','1042','1043','1044','1065','1069']
test_runs = [8636,8653,8693,8707,8853,8861]
test_pixels = ['1076']

# %%
plt.step(bin_edges[50:300],LDETenergy[8840]['1086'][50:300])

# %%
reload(bi_fit)
# Out:
# <module 'DataAnalysis.bi_fit_functions' from '/Users/arleeshelby/NabCalibration/DataAnalysis/bi_fit_functions.py'>

# %%
LDET_test_df = bf.get_results_df(bi_fit.get_UDETbi_fit_results, LDETenergy, bin_edges, test_pixels, test_runs, plot=True,detector_type='LDET')
# Out:
# failed Bi fit for run: 8653, pixel: 1076, region 1
# failed Bi fit for run: 8707, pixel: 1076, region 1

# %%
simulated_keV_values = np.array([22.269661+3,35.276915+3,450.020179+3,522.714534+3,535.039+3,
                                 944.193705+3,1016.613371+3,1029.008589+3])
simulated_keV_errors = np.array([0.005846,0.002800,0.003731,0.005186,0.013013,0.002459,0.004933,0.012757])

LDETsimulated_keV_values = np.array([22.269661+30,35.276915+30,450.020179+30,522.714534+30,535.039+30,
                                     944.193705+30,1016.613371+30,1029.008589+30])
LDETsimulated_keV_errors = np.array([0.005846,0.002800,0.003731,0.005186,0.013013,0.002459,0.004933,0.012757])

# %%
calibration_peak_data,calibration_width_data,calibration_amp_data = bf.get_cal_peaks_df(UDET_df,simulated_keV_values,simulated_keV_errors)

# %%
LDETcalibration_peak_data,LDETcalibration_width_data,LDETcalibration_amp_data = bf.get_cal_peaks_df(LDET_df_test_props,LDETsimulated_keV_values,LDETsimulated_keV_errors)

# %%
plotf.plot_peak_fit_params(LDETcalibration_width_data,peak='peak3',bottom_ylim=-1,top_ylim=30)

# %%
pixels = list(LDETcalibration_amp_data.keys())
for pixel in pixels:
    runs = list(LDETcalibration_amp_data[pixel].keys())
    for run in runs:
        try:
            amp = LDETcalibration_amp_data[pixel][run]['peak4']['value']
            error = LDETcalibration_amp_data[pixel][run]['peak4']['error']
            if amp<1:
                print(pixel,run,amp,error)
        except Exception as e:
            continue
# Out:
# 1021 8829 1.7848680837762032e-06 1.7388259794761258

# %%
pixels = list(calibration_amp_data.keys())
for pixel in pixels:
    runs = list(calibration_amp_data[pixel].keys())
    for run in runs:
        try:
            amp = calibration_amp_data[pixel][run]['peak3']['value']
            error = calibration_amp_data[pixel][run]['peak3']['error']
            if amp<50:
                print(pixel,run,amp,error)
        except Exception as e:
            continue
# Out:
# 27 8630 25.195325433268458 2.8870601180860294
# 27 8689 20.16406327607819 2.7553900750119285
# 27 8840 26.215250694761107 2.679914404456502
# 32 8654 28.559497359614703 2.436890575712369
# 32 8708 30.35968449747513 2.315247909990773
# 32 8854 35.382960261152455 6.9852537267654045
# 52 8709 38.55823589020378 2.6544165315322084
# 52 8855 42.78171445645725 4.121369505707245
# 64 8681 43.290597271643044 3.3983406924306316
# 87 8626 24.24988269925393 2.3384229014728377
# 87 8685 38.42401784275149 3.243877862592101
# 89 8682 23.912293490278397 1.9981224339708248
# 100 8652 33.7856681873026 3.141050947045069
# 100 8850 29.872990896889075 2.715439049203202
# 109 8651 31.037563377939776 2.6656658215987483
# 109 8652 19.65501556910509 1.8493353943048159
# 109 8705 29.56544381544192 3.0354392062414175
# 110 8649 40.45632487668338 4.472910092887661
# 110 8716 27.771351887385837 2.071449073886249
# 110 8845 35.169549800481576 2.7331821666046148

# %%
reload(plotf)
# Out:
# <module 'DataAnalysis.plot_functions' from '/Users/arleeshelby/NabCalibration/DataAnalysis/plot_functions.py'>

# %%
plotf.plot_peak_fit_params(LDETcalibration_width_data,peak='peak6',bottom_ylim=None,top_ylim=None,
                           title='LDET 207Bi 975 keV Peak Width',ylabel='Width (ADC)')

# %%
plotf.plot_peak_fit_params(calibration_width_data,peak='peak6',bottom_ylim=None,top_ylim=None,
                           title='UDET 207Bi 975 keV Peak Width',ylabel='Width (ADC)')

# %%
LDETgain['1031']
# Out:
# {8636: {'value': 3.078388505009857, 'error': 0.004550471477760229},
#  8652: {'value': 3.07972594207769, 'error': 0.0029844069779146718},
#  8693: {'value': 3.0800096211442103, 'error': 0.0014978555896673048},
#  8706: {'value': 3.0785351327536588, 'error': 0.0015399522741969165},
#  8718: {'value': 3.079059643867768, 'error': 0.002546731004839642},
#  8830: {'value': 3.091287199216971, 'error': 0.0013519925218522823},
#  8850: {'value': 3.0873981587029813, 'error': 0.001662027537385957},
#  8861: {'value': 3.0858188401036273, 'error': 0.0011402135884083023}}

# %%
calibration_linear_results = bf.calibrate_data(calibration_peak_data,calibration_amp_data,calibration_order='linear')
calibration_quadratic_results = bf.calibrate_data(calibration_peak_data,calibration_amp_data,calibration_order='quadratic')

# %%
reload(bf)
# Out:
# <module 'DataAnalysis.basic_functions' from '/Users/arleeshelby/NabCalibration/DataAnalysis/basic_functions.py'>

# %%
LDETcalibration_linear_results = bf.calibrate_data(LDETcalibration_peak_data,LDETcalibration_amp_data,calibration_order='linear',detector='LDET')
LDETcalibration_quadratic_results = bf.calibrate_data(LDETcalibration_peak_data,LDETcalibration_amp_data,calibration_order='quadratic',detector='LDET')

# %%
keys = list(calibration_linear_results.keys())
runs_calibrated = []
for i in keys:
    runs = list(calibration_linear_results[i].keys())
    for j in range(len(runs)):
        if any(value==str(runs[j]) for value in runs_calibrated):
            pass
        else:
            runs_calibrated.append(str(runs[j]))

# %%
len(runs_calibrated)
# Out:
# 104

# %%
runs_calibrated
with open('DatabaseFiles/Runs/calibrated_runs.txt', 'w') as file:
    file.write('\n'.join(runs_calibrated))

# %%
with open('DatabaseFiles/Runs/run_db.csv') as f:
    csv.DictReader(f)
    metadata = pd.read_csv(f)

# %%
metadata
# Out:
#      run_number  UDET_bias  LDET_bias    HV   MAIN   UDET        date  \
# 0          8655      300.0      300.0  27.0  137.0  137.0  2025-10-14
# 1          8709      300.0      300.0  27.0  137.0  137.0  2025-10-21
# 2          8855      300.0      300.0  27.0  137.0  137.0  2025-10-31
# 3          8646      300.0      300.0  27.0  137.0  137.0  2025-10-14
# 4          8848      300.0      300.0  27.0  137.0  137.0  2025-10-30
# ..          ...        ...        ...   ...    ...    ...         ...
# 99         8720      300.0      300.0  27.0  137.0  137.0  2025-10-22
# 100        8826      300.0      300.0  27.0  137.0  137.0  2025-10-29
# 101        8857      300.0      300.0  27.0  137.0  137.0  2025-10-31
# 102        8719      300.0      300.0  27.0  137.0  137.0  2025-10-22
# 103        8829      300.0      300.0  27.0  137.0  137.0  2025-10-29
#
#     start_time  end_time          ExB  UDET_armor   UDET_ring  LDET_armor  \
# 0     20:51:38  20:51:36 -1499.050847  134.458618  119.984912  129.964194
# 1     19:48:30  19:48:28 -1499.000000  134.458499  119.991606  129.974482
# 2     15:31:48  15:31:46 -1499.117949  134.275259  120.013290  130.077537
# 3     15:35:23  15:35:21 -1499.078125  134.468330  119.999757  129.926447
# 4     20:20:45  20:20:43 -1499.000000  134.306473  120.004832  130.048831
# ..         ...       ...          ...         ...         ...         ...
# 99    16:18:29  16:50:08 -1499.028090  134.445196  120.003004  130.028883
# 100   19:53:08  20:23:09 -1499.386364  134.329690  119.994170  130.084202
# 101   16:42:53  17:17:46 -1499.062802  134.281502  120.014718  130.094448
# 102   15:45:26  16:15:26 -1499.269962  134.445041  120.003693  130.040813
# 103   21:34:02  22:04:47 -1499.168182  134.328398  120.006081  130.061301
#
#      UDET_leakage  LDET_leakage
# 0        0.007057      35.94986
# 1        0.007585      35.96716
# 2        0.007338      35.86735
# 3        0.007080      35.94495
# 4        0.007573      35.63690
# ..            ...           ...
# 99       0.007329      36.64413
# 100      0.008578      36.42743
# 101      0.007322      36.35307
# 102      0.007344      36.53752
# 103      0.008342      36.12118
#
# [104 rows x 15 columns]

# %%
plotf.plot_goodness_of_fit(calibration_linear_results,chi2=False,reduced_chi2=True,bottom_ylim=None,top_ylim=5)

# %%
plotf.plot_goodness_of_fit(LDETcalibration_linear_results,chi2=False,reduced_chi2=True,bottom_ylim=-1,top_ylim=50)

# %%
plotf.plot_calibration_results('48',calibration_linear_results,metadata,gain=True)

# %%
plotf.plot_calibration_results('53',calibration_linear_results,metadata,gain=True)

# %%
reload(plotf)
# Out:
# <module 'DataAnalysis.plot_functions' from '/Users/arleeshelby/NabCalibration/DataAnalysis/plot_functions.py'>

# %%
LDETgain['1076']
# Out:
# {8636: {'value': 3.042539013678508, 'error': 0.0014219346390862845},
#  8653: {'value': 3.0438077531529326, 'error': 0.0004073337191270996},
#  8693: {'value': 3.0422043044183087, 'error': 0.00042781481531026},
#  8707: {'value': 3.0434399460897503, 'error': 0.0005385467852917457},
#  8853: {'value': 3.049025002094108, 'error': 0.0004851817418311249},
#  8861: {'value': 3.0491984466613027, 'error': 0.000393310817926949}}

# %%
LDETcalibration_linear_results['1076'][8636]
# Out:
# <h2>Fit Result</h2> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>7</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>8</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>2</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 26.0170971</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 4.33618286</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 13.4344989</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 13.5933820</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>m</td><td style='text-align:left'> 3.04253901</td><td style='text-align:left'> 0.00142193</td><td style='text-align:left'>(0.05%)</td><td style='text-align:left'>3</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b</td><td style='text-align:left'>-7.94804158</td><td style='text-align:left'> 1.31130902</td><td style='text-align:left'>(16.50%)</td><td style='text-align:left'>0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>m</td><td style='text-align:left'>b</td><td style='text-align:right'>-0.9779</td></tr></table>

# %%
plotf.plot_calibration_results('1023',LDETcalibration_linear_results,metadata,offset=True,
                               title='Offset Over Time: Pixel 1023',ylabel='Offset (ADC)',
                              bottom_ylim=-14,top_ylim=-6)

# %%
plotf.plot_calibration_results('1076',LDETcalibration_linear_results,metadata,offset=True,
                               title='Offset Over Time: Pixel 1076',ylabel='Offset (ADC)',
                              bottom_ylim=-14,top_ylim=-6)

# %%
LDETgain['1023']
# Out:
# {8628: {'value': 3.108324344000004, 'error': 0.002009247632136299},
#  8687: {'value': 3.105886197599836, 'error': 0.0012654916088018098},
#  8826: {'value': 3.110177309656808, 'error': 0.0020437850487942067},
#  8842: {'value': 3.112258283955452, 'error': 0.002160783653273126},
#  8857: {'value': 3.1122981046579636, 'error': 0.003786129036152517}}

# %%
gain['32']
# Out:
# {8637: {'value': 2.9891674526205283, 'error': 0.0004159161347253773},
#  8694: {'value': 2.9887192501416178, 'error': 0.0002290882554689466},
#  8860: {'value': 2.9884861951231576, 'error': 0.0007162140314674762}}

# %%
pixels = list(LDETgain.keys())
for pixel in pixels:
    runs = list(LDETgain[pixel].keys())
    print(pixel,runs)
# Out:
# 1012 [8719, 8829]
# 1013 [8651, 8705, 8849]
# 1020 [8720]
# 1022 [8622, 8681]
# 1023 [8628, 8687, 8720, 8826, 8842, 8857]
# 1026 [8627, 8659, 8686, 8712, 8838]
# 1027 [8718, 8830]
# 1029 [8697, 8717, 8825, 8863, 8864]
# 1030 [8626, 8627, 8636, 8659, 8685, 8686, 8693, 8712, 8718, 8830, 8837, 8838, 8861]
# 1031 [8636, 8652, 8693, 8706, 8718, 8830, 8850, 8861]
# 1033 [8627, 8659, 8686, 8712, 8838]
# 1037 [8632, 8650, 8685, 8691, 8704, 8837, 8843, 8844]
# 1039 [8644, 8863]
# 1040 [8626, 8651, 8685, 8705, 8837, 8849]
# 1041 [8632, 8636, 8637, 8650, 8653, 8691, 8693, 8694, 8704, 8843, 8844, 8853, 8860, 8861]
# 1042 [8624, 8653, 8683, 8707, 8834, 8853]
# 1043 [8644]
# 1044 [8626, 8685, 8837]
# 1047 [8635, 8651, 8692, 8705, 8862]
# 1048 [8622, 8651, 8681, 8705]
# 1049 [8628, 8650, 8687, 8704, 8842, 8844]
# 1051 [8635, 8651, 8692, 8705, 8849, 8862]
# 1052 [8622, 8628, 8637, 8650, 8681, 8687, 8694, 8704, 8842, 8860]
# 1053 [8624, 8628, 8637, 8654, 8683, 8687, 8694, 8708, 8834, 8842, 8854, 8860]
# 1054 [8624, 8630, 8647, 8683, 8692, 8834, 8840, 8847]
# 1055 [8622, 8630, 8651, 8681, 8705, 8840, 8849]
# 1056 [8628, 8650, 8687, 8704, 8842, 8844]
# 1060 [8652, 8706, 8850]
# 1061 [8649, 8713, 8716, 8845]
# 1063 [8636, 8693]
# 1064 [8623, 8652, 8682, 8706, 8835, 8850]
# 1065 [8629, 8643, 8649, 8688, 8696, 8713, 8716, 8841, 8845, 8859]
# 1066 [8625, 8684, 8708, 8832, 8854]
# 1067 [8631, 8635, 8647, 8652, 8690, 8692, 8706, 8839, 8847, 8850, 8862]
# 1068 [8622, 8649, 8681, 8713, 8716, 8845]
# 1069 [8628, 8687, 8842]
# 1072 [8636, 8693, 8861]
# 1073 [8623, 8653, 8682, 8835, 8853]
# 1074 [8629, 8688, 8715, 8841, 8846]
# 1076 [8636, 8653, 8693, 8707, 8853, 8861]
# 1077 [8623, 8629, 8648, 8682, 8688, 8715, 8835, 8841, 8846]
# 1078 [8629, 8655, 8688, 8709, 8721, 8827, 8841, 8855, 8865]
# 1079 [8636, 8646, 8693, 8721, 8827, 8848, 8861, 8865]
# 1080 [8623, 8636, 8653, 8682, 8693, 8707, 8835, 8853, 8861]
# 1081 [8623, 8629, 8648, 8682, 8688, 8835, 8841, 8846]
# 1084 [8624, 8637, 8653, 8683, 8694, 8707, 8834, 8853]
# 1085 [8624, 8630, 8683, 8689, 8715, 8834, 8840, 8846]
# 1086 [8630, 8689, 8840]
# 1087 [8637, 8694, 8860]
# 1088 [8624, 8653, 8683, 8707, 8834, 8853]
# 1089 [8630, 8645, 8648, 8689, 8698, 8715, 8840, 8846, 8858]
# 1090 [8658, 8711, 8831]
# 1091 [8637, 8653, 8694, 8707, 8853, 8860]
# 1092 [8624, 8648, 8683, 8715, 8834, 8846]
# 1094 [8637, 8654, 8694, 8708, 8854, 8860]
# 1095 [8624, 8625, 8647, 8654, 8683, 8684, 8708, 8828, 8832, 8834, 8847, 8854]
# 1096 [8630, 8647, 8828, 8840, 8847]
# 1098 [8654, 8708, 8854]
# 1099 [8625, 8647, 8684, 8828, 8847]
# 1100 [8656, 8657, 8699, 8710, 8824, 8856]
# 1101 [8637, 8694, 8860]
# 1102 [8624, 8654, 8683, 8708, 8834, 8854]
# 1105 [8625, 8631, 8646, 8684, 8690, 8721, 8827, 8832, 8839, 8848, 8865]
# 1107 [8643, 8696, 8859]
# 1108 [8625, 8655, 8684, 8709, 8721, 8827, 8832, 8855, 8865]
# 1109 [8631, 8646, 8690, 8839, 8848]
# 1111 [8643, 8696, 8709, 8855, 8859]
# 1116 [8645, 8655, 8698, 8709, 8855, 8858]
# 1117 [8646, 8658, 8711, 8831, 8848]

# %%
reload(bf)
# Out:
# <module 'DataAnalysis.basic_functions' from '/Users/arleeshelby/NabCalibration/DataAnalysis/basic_functions.py'>

# %%
gain = bf.get_calibration_fit_params(calibration_linear_results,gain=True)
offset = bf.get_calibration_fit_params(calibration_linear_results,offset=True)

# %%
LDETgain = bf.get_calibration_fit_params(LDETcalibration_linear_results,gain=True)
LDEToffset = bf.get_calibration_fit_params(LDETcalibration_linear_results,offset=True)

# %%
quad = bf.get_calibration_fit_params(calibration_quadratic_results,quad=True)
LDETquad = bf.get_calibration_fit_params(LDETcalibration_quadratic_results,quad=True)

# %%
quad_gain = bf.get_calibration_fit_params(calibration_quadratic_results,gain=True)
LDETquad_gain = bf.get_calibration_fit_params(LDETcalibration_quadratic_results,gain=True)
quad_offset = bf.get_calibration_fit_params(calibration_quadratic_results,offset=True)
LDETquad_offset = bf.get_calibration_fit_params(LDETcalibration_quadratic_results,offset=True)

# %%
average_gain, average_gain_error, gain_std = bf.get_calibration_param_props(gain)
average_gain_weighted, average_gain_error_weighted, gain_std_weighted = bf.get_calibration_param_props(gain,weighted=True)

average_offset, average_offset_error, offset_std = bf.get_calibration_param_props(offset)
average_offset_weighted, average_offset_error_weighted, offset_std_weighted = bf.get_calibration_param_props(offset,weighted=True)

# %%
LDETaverage_gain, LDETaverage_gain_error, LDETgain_std = bf.get_calibration_param_props(LDETgain)
LDETaverage_gain_weighted, LDETaverage_gain_error_weighted, LDETgain_std_weighted = bf.get_calibration_param_props(LDETgain,weighted=True)
LDETaverage_offset, LDETaverage_offset_error, LDEToffset_std = bf.get_calibration_param_props(LDEToffset)
LDETaverage_offset_weighted, LDETaverage_offset_error_weighted, LDEToffset_std_weighted = bf.get_calibration_param_props(LDEToffset,weighted=True)

# %%
average_quad_weighted, average_quad_error_weighted, quad_std_weighted = bf.get_calibration_param_props(quad,weighted=True)
LDETaverage_quad_weighted, LDETaverage_quad_error_weighted, LDETquad_std_weighted = bf.get_calibration_param_props(LDETquad,weighted=True)

# %%
reload(plotf)
# Out:
# <module 'DataAnalysis.plot_functions' from '/Users/arleeshelby/NabCalibration/DataAnalysis/plot_functions.py'>

# %%
plotf.plot_calibration_param_props(average_gain_weighted,LDETparam_prop_df=LDETaverage_gain_weighted,title='Average Gain per Pixel',ylabel='Gain (ADC/keV)')

# %%
plotf.plot_calibration_param_props(gain_std_weighted,yscale='log',LDETparam_prop_df=LDETgain_std_weighted,
                                   title='Average Gain Variation per Pixel',ylabel='Variation (ADC/keV)',
                                   bottom_ylim=5e-5,top_ylim=3e-3)

# %%
plotf.plot_calibration_param_props(average_gain_error,yscale='log',LDETparam_prop_df=LDETaverage_gain_error,
                                   title='Average Gain Uncertainty per Pixel',ylabel='Uncertainty (ADC/keV)',
                                   bottom_ylim=5e-5,top_ylim=4e-3)

# %%
plotf.plot_calibration_param_props(average_offset_weighted,LDETparam_prop_df=LDETaverage_offset_weighted,title='Average Offset per Pixel',ylabel='Offset (ADC)')

# %%
plotf.plot_calibration_param_props(offset_std_weighted,yscale='log',LDETparam_prop_df=LDEToffset_std_weighted,
                                   title='Average Offset Variation per Pixel',ylabel='Variation (ADC)',
                                   bottom_ylim=5e-2,top_ylim=4)

# %%
plotf.plot_calibration_param_props(average_offset_error,yscale='log',LDETparam_prop_df=LDETaverage_offset_error,
                                   title='Average Offset Uncertainty per Pixel',ylabel='Uncertainty (ADC)',
                                   bottom_ylim=5e-2,top_ylim=4)

# %%
plotf.plot_calibration_param_props(average_quad_weighted,LDETparam_prop_df=LDETaverage_quad_weighted,title='Average Quadratic Term per Pixel',ylabel='Quadratic Term (ADC/keV^2)')

# %%
plotf.plot_calibration_param_props(average_quad_error_weighted,yscale='log',LDETparam_prop_df=LDETaverage_quad_error_weighted,
                                   title='Average Quadratic Term Uncertainty per Pixel',ylabel='Uncertainty (ADC/keV^2)',
                                   bottom_ylim=1e-7,top_ylim=9e-5)

# %%
plotf.plot_calibration_param_props(quad_std_weighted,yscale='log',LDETparam_prop_df=LDETquad_std_weighted,
                                   title='Average Quadratic Term Variation per Pixel',ylabel='Variation (ADC/keV^2)',
                                   bottom_ylim=1e-7,top_ylim=9e-5)

# %%
for key,value in LDETaverage_offset_error.items():
    if value>3:
        print(key,value)
# Out:
# 1020 41.39943069230812

# %%
pixel = '1076'
runs = list(LDEToffset[pixel].keys())
for run in runs:
    print(LDEToffset[pixel][run]['error']/LDETgain[pixel][run]['value'])
# Out:
# 0.4309916849553007
# 0.1211996211344192
# 0.12829772285548546
# 0.16030945332094837
# 0.1416065330475903
# 0.11599705097274644

# %%
nrows,ncols=1,1
py.figure(figsize=((16)*ncols,(4)*nrows))
ax=py.subplot(nrows,ncols,1)

pixels = list(offset.keys())
int_pixels = list(map(int, pixels))
for pixel in pixels:
    if pixel=='95':
        continue
    else:
        runs = list(offset[pixel].keys())
        all_uncert = []
        for run in runs:
            uncert = offset[pixel][run]['error']/gain[pixel][run]['value']
            all_uncert.append(uncert)
            if uncert>0.5:
                # print(pixel,run,uncert)
                pass
            if pixel=='11' and run==8655:
                ax.scatter(int(pixel),uncert,color='C0',s=45,alpha=0.55,label='UDET')
            else:
                ax.scatter(int(pixel),uncert,color='C0',s=45,alpha=0.55)
        if any(value<0.3 for value in all_uncert):
            pass
        else:
            print(pixel)
pixels = list(LDEToffset.keys())
for pixel in pixels:
    if pixel=='1043' or pixel=='1054':
        continue
    else:
        runs = list(LDEToffset[pixel].keys())
        LDETall_uncert = []
        for run in runs:
            uncert = LDEToffset[pixel][run]['error']/LDETgain[pixel][run]['value']
            LDETall_uncert.append(uncert)
            if uncert>2:
                # print(pixel,run,uncert)
                pass
            if pixel=='1012' and run==8719:
                ax.scatter(int(pixel)-1000,uncert,color='C1',s=45,alpha=0.55,label='LDET')
            else:
                ax.scatter(int(pixel)-1000,uncert,color='C1',s=45,alpha=0.55)
        if any(value<0.3 for value in LDETall_uncert):
            pass
        else:
            print(pixel)
ax.set_xticks(range(min(int_pixels),max(int_pixels),10))
ax.set_ylim(0,2)
ax.axhline(0.3,color = 'black', linestyle='dashed',label = '0.3 keV',linewidth=2)
ax.axhline(1.5,color = 'red', linestyle='dashdot',label = '1.5 keV',linewidth=2)
ax.set_xlabel('Pixel',fontsize=15)
ax.set_ylabel('Uncertainty (keV)',fontsize=15)
ax.set_title('Offset Uncertainty Over ~3 Week Period',fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.legend(fontsize=15)
plt.show()
# Out:
# 1012 0.885792452370848
# 1020 0.885792452370848
# 1022 0.885792452370848
# 1023 0.885792452370848
# 1031 0.885792452370848
# 1069 0.885792452370848
# 1086 0.885792452370848

# %%
LDEToffset['1012']
# Out:
# {8719: {'value': -13.639216001726547, 'error': 3.2860278221069557},
#  8829: {'value': -15.399724739586103, 'error': 2.4400162348763}}

# %%
y = np.arange(0,1600)
diff = {}
pixels = list(gain.keys())
for pixel in pixels:
    diff[i] = {}
    runs = gain.keys
    for run in cal_result[i]['m'].keys():
        quad = cal_result[i]['q1'][j]*y**2 +cal_result[i]['q2'][j]*y + cal_result[i]['q3'][j]
        lin = cal_result[i]['m'][j]*y + cal_result[i]['b'][j]
        full_diff = quad-lin
        if cal_result[i]['q1'][j]>0:
            diff[i][j] = np.min(full_diff)
        if cal_result[i]['q1'][j]<0:
            diff[i][j] = np.max(full_diff)

# %%
y = np.arange(0,1600)
pixels = list(offset.keys())
int_pixels = list(map(int, pixels))
diff = {}
for pixel in pixels:
    if pixel=='95':
        continue
    else:
        diff[pixel] = {}
        runs = list(offset[pixel].keys())
        all_uncert = []
        for run in runs:
            quadratic = quad[pixel][run]['value']*y**2 + quad_gain[pixel][run]['value']*y + quad_offset[pixel][run]['value']
            lin = gain[pixel][run]['value']*y + offset[pixel][run]['value']
            full_diff = quadratic-lin
            if quad[pixel][run]['value']>0:
                diff[pixel][run] = np.min(full_diff)/gain[pixel][run]['value']
            if quad[pixel][run]['value']<0:
                diff[pixel][run] = np.max(full_diff)/gain[pixel][run]['value']

# %%
y = np.arange(0,1600)
pixels = list(LDEToffset.keys())
LDETint_pixels = list(map(int, pixels))
LDETdiff = {}
for pixel in pixels:
    if pixel=='1043' or pixel=='1054':
        continue
    else:
        LDETdiff[pixel] = {}
        runs = list(LDEToffset[pixel].keys())
        all_uncert = []
        for run in runs:
            quadratic = LDETquad[pixel][run]['value']*y**2 + LDETquad_gain[pixel][run]['value']*y + LDETquad_offset[pixel][run]['value']
            lin = LDETgain[pixel][run]['value']*y + LDEToffset[pixel][run]['value']
            full_diff = quadratic-lin
            if LDETquad[pixel][run]['value']>0:
                LDETdiff[pixel][run] = np.min(full_diff)/LDETgain[pixel][run]['value']
            if LDETquad[pixel][run]['value']<0:
                LDETdiff[pixel][run] = np.max(full_diff)/LDETgain[pixel][run]['value']

# %%
nrows,ncols=1,1
py.figure(figsize=((16)*ncols,(4)*nrows))
ax=py.subplot(nrows,ncols,1)

pixels = list(diff.keys())
int_pixels = list(map(int, pixels))
for pixel in pixels:
    if pixel=='95':
        continue
    else:
        runs = list(diff[pixel].keys())
        all_uncert = []
        for run in runs:
            uncert = np.abs(diff[pixel][run])
            all_uncert.append(uncert)
            if pixel=='11' and run==8655:
                ax.scatter(int(pixel),uncert,color='C0',s=45,alpha=0.55,label='UDET')
            else:
                ax.scatter(int(pixel),uncert,color='C0',s=45,alpha=0.55)
        if any(value<1.5 for value in all_uncert):
            pass
        else:
            print(pixel)
pixels = list(LDETdiff.keys())
for pixel in pixels:
    if pixel=='1043' or pixel=='1054':
        continue
    else:
        runs = list(LDETdiff[pixel].keys())
        LDETall_uncert = []
        for run in runs:
            uncert = np.abs(LDETdiff[pixel][run])
            LDETall_uncert.append(uncert)
            if pixel=='1012' and run==8719:
                ax.scatter(int(pixel)-1000,uncert,color='C1',s=45,alpha=0.55,label='LDET')
            else:
                ax.scatter(int(pixel)-1000,uncert,color='C1',s=45,alpha=0.55)
        if any(value<1.5 for value in LDETall_uncert):
            pass
        else:
            print(pixel)
ax.set_xticks(range(min(int_pixels),max(int_pixels),10))
ax.set_ylim(-0.1,2)
# ax.axhline(0.3,color = 'black', linestyle='dashed',label = '0.3 keV',linewidth=2)
ax.axhline(1.5,color = 'red', linestyle='dashdot',label = '1.5 keV',linewidth=2)
ax.set_xlabel('Pixel',fontsize=15)
ax.set_ylabel('Residual (keV)',fontsize=15)
ax.set_title('Linear and Quadratic Residual Over ~3 Week Period',fontsize=15)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.legend(fontsize=15)
plt.show()
